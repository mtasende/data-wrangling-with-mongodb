# %% [markdown]
# # Quiz 1

# %%
"""
Use an aggregation query to answer the following question. 

What is the most common city name in our cities collection?

Your first attempt probably identified None as the most frequently occurring
city name. What that actually means is that there are a number of cities
without a name field at all. It's strange that such documents would exist in
this collection and, depending on your situation, might actually warrant
further cleaning. 

To solve this problem the right way, we should really ignore cities that don't
have a name specified. As a hint ask yourself what pipeline operator allows us
to simply filter input? How do we test for the existence of a field?

Please modify only the 'make_pipeline' function so that it creates and returns
an aggregation pipeline that can be passed to the MongoDB aggregate function.
As in our examples in this lesson, the aggregation pipeline should be a list of
one or more dictionary objects. Please review the lesson examples if you are
unsure of the syntax.

Your code will be run against a MongoDB instance that we have provided. If you
want to run this code locally on your machine, you have to install MongoDB, 
download and insert the dataset. For instructions related to MongoDB setup and
datasets please see Course Materials.

Please note that the dataset you are using here is a different version of the
cities collection provided in the course materials. If you attempt some of the
same queries that we look at in the problem set, your results may be different.
"""

def get_db(db_name):
    from pymongo import MongoClient
    client = MongoClient('localhost:27017')
    db = client[db_name]
    return db

# %%
# For debugging
def aggregate(db, pipeline):
    return [doc for doc in db.cities.aggregate(pipeline)]

db = get_db('examples')

# %%
aggregate(db, [
    {"$match": {"country": {"$eq": "India"}}},
    {"$match": {"name": {"$exists": True, "$ne": None}}},
    {"$group": {"_id": "$name", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}},
    {"$limit": 5}
])
# Out:
# [{u'_id': u'Patan', u'count': 5},
#  {u'_id': u'Shahpura', u'count': 4},
#  {u'_id': u'Gangapur', u'count': 3},
#  {u'_id': u'Deori', u'count': 3},
#  {u'_id': u'Bilaspur', u'count': 3}]

# %%
def make_pipeline():
    # complete the aggregation pipeline
    pipeline = [
        {"$match": {"country": {"$eq": "India"}}},
        {"$match": {"name": {"$exists": True, "$ne": None}}},
        {"$group": {"_id": "$name", "count": {"$sum": 1}}},
        {"$sort": {"count": -1}},
        {"$limit": 1}
    ]
    return pipeline

# %%
def aggregate(db, pipeline):
    return [doc for doc in db.cities.aggregate(pipeline)]


if __name__ == '__main__':
    # The following statements will be used to test your code by the grader.
    # Any modifications to the code past this point will not be reflected by
    # the Test Run.
    db = get_db('examples')
    pipeline = make_pipeline()
    result = aggregate(db, pipeline)
    import pprint
    pprint.pprint(result[0])
    assert len(result) == 1
    #assert result[0] == {'_id': 'Shahpur', 'count': 6}
# Out:
# {u'_id': u'Patan', u'count': 5}

# %% [markdown]
# # Quiz 2

# %%
"""
Use an aggregation query to answer the following question. 

Which Region in India has the largest number of cities with longitude between
75 and 80?

Please modify only the 'make_pipeline' function so that it creates and returns
an aggregation pipeline that can be passed to the MongoDB aggregate function.
As in our examples in this lesson, the aggregation pipeline should be a list of
one or more dictionary objects. Please review the lesson examples if you are
unsure of the syntax.

Your code will be run against a MongoDB instance that we have provided. If you
want to run this code locally on your machine, you have to install MongoDB,
download and insert the dataset. For instructions related to MongoDB setup and
datasets please see Course Materials.

Please note that the dataset you are using here is a different version of the
cities collection provided in the course materials. If you attempt some of the
same queries that we look at in the problem set, your results may be different.
"""

def get_db(db_name):
    from pymongo import MongoClient
    client = MongoClient('localhost:27017')
    db = client[db_name]
    return db

# %%
# For debugging
def aggregate(db, pipeline):
    return [doc for doc in db.cities.aggregate(pipeline)]

db = get_db('examples')

# %%
aggregate(db, [
    {"$match": {"lon": {""}}}
    {"$limit": 1}
])
# Out:
# [{u'_id': ObjectId('5ca79c02873d8102a816e2ca'),
#   u'country': u'India',
#   u'elevation': 1855.0,
#   u'isPartOf': [u'Jammu and Kashmir', u'Udhampur district'],
#   u'lat': 75.28,
#   u'lon': 33.08,
#   u'name': u'Kud',
#   u'population': 1140,
#   u'timeZone': u'Indian Standard Time'}]

# %%
aggregate(db, [
    {"$match": {"country": {"$eq": "India"}}},
    {"$match": {"isPartOf": {"$exists": True, "$ne": None}}},
    {"$match": {"$and": [{"lon":{"$gte": 75.0}}, {"lon": {"$lte": 80.0}}]}},
    {"$unwind": "$isPartOf"},
    {"$group": {"_id": "$isPartOf", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}},
    {"$limit": 5}
])
# Out:
# []

# %%
def make_pipeline():
    # complete the aggregation pipeline
    pipeline = [
        {"$match": {"country": {"$eq": "India"}}},
        {"$match": {"isPartOf": {"$exists": True, "$ne": None}}},
        {"$match": {"$and": [{"lon":{"$gte": 75.0}}, {"lon": {"$lte": 80.0}}]}},
        {"$unwind": "$isPartOf"},
        {"$group": {"_id": "$isPartOf", "count": {"$sum": 1}}},
        {"$sort": {"count": -1}},
        {"$limit": 1}
    ]
    return pipeline

# %%
def aggregate(db, pipeline):
    return [doc for doc in db.cities.aggregate(pipeline)]

if __name__ == '__main__':
    # The following statements will be used to test your code by the grader.
    # Any modifications to the code past this point will not be reflected by
    # the Test Run.
    db = get_db('examples')
    pipeline = make_pipeline()
    result = aggregate(db, pipeline)
    """import pprint
    pprint.pprint(result[0])
    assert len(result) == 1
    assert result[0]["_id"] == 'Tamil Nadu'
    assert result[0]["count"] == 424"""

# %%
result
# Out:
# []

# %% [markdown]
# # Quiz 3

# %%
"""
Use an aggregation query to answer the following question. 

Extrapolating from an earlier exercise in this lesson, find the average
regional city population for all countries in the cities collection. What we
are asking here is that you first calculate the average city population for each
region in a country and then calculate the average of all the regional averages
for a country.
  As a hint, _id fields in group stages need not be single values. They can
also be compound keys (documents composed of multiple fields). You will use the
same aggregation operator in more than one stage in writing this aggregation
query. I encourage you to write it one stage at a time and test after writing
each stage.

Please modify only the 'make_pipeline' function so that it creates and returns
an aggregation  pipeline that can be passed to the MongoDB aggregate function.
As in our examples in this lesson, the aggregation pipeline should be a list of
one or more dictionary objects. Please review the lesson examples if you are
unsure of the syntax.

Your code will be run against a MongoDB instance that we have provided. If you
want to run this code locally on your machine, you have to install MongoDB,
download and insert the dataset. For instructions related to MongoDB setup and
datasets please see Course Materials.

Please note that the dataset you are using here is a different version of the
cities collection provided in the course materials. If you attempt some of the
same queries that we look at in the problem set, your results may be different.
"""

def get_db(db_name):
    from pymongo import MongoClient
    client = MongoClient('localhost:27017')
    db = client[db_name]
    return db

# %%
# For debugging
def aggregate(db, pipeline):
    return [doc for doc in db.cities.aggregate(pipeline)]
db = get_db('examples')

# %%
aggregate(db, [
    {"$limit": 1}
])
# Out:
# [{u'_id': ObjectId('5ca79c02873d8102a816e2ca'),
#   u'country': u'India',
#   u'elevation': 1855.0,
#   u'isPartOf': [u'Jammu and Kashmir', u'Udhampur district'],
#   u'lat': 75.28,
#   u'lon': 33.08,
#   u'name': u'Kud',
#   u'population': 1140,
#   u'timeZone': u'Indian Standard Time'}]

# %%
aggregate(db, [
    {"$match": {"population": {"$exists": True, "$ne": None},
                "country": {"$exists": True, "$ne": None}
               }},
    {"$unwind": "$isPartOf"},
    {"$group": {"_id": "$isPartOf", 
                "avg": {"$avg": "$population"}, 
                "country": {"$first": "$country"}}},
    {"$group": {"_id": "$country", "avg": {"$avg": "$avg"}}},
    {"$sort": {"avg": -1}}
    #{"$limit": 5}
])
# Out:
# [{u'_id': u'The_Democratic_Republic_Of_Congo', u'avg': 9046000.0},
#  {u'_id': u'Turkey', u'avg': 1945457.0},
#  {u'_id': u'United Kingdom', u'avg': 1864957.8653846155},
#  {u'_id': u'Saudi Arabia', u'avg': 1826254.75},
#  {u'_id': u'Cuba', u'avg': 1701228.0},
#  {u'_id': u'China', u'avg': 1294543.23975458},
#  {u'_id': u'Kenya', u'avg': 1226727.4285714286},
#  {u'_id': u'Bangladesh', u'avg': 1193317.0925925926},
#  {u'_id': u'Ghana', u'avg': 1185798.5},
#  {u'_id': u'Tunisia', u'avg': 1138517.5},
#  {u'_id': u'Honduras', u'avg': 1126534.0},
#  {u'_id': u'Zambia', u'avg': 1103957.4285714286},
#  {u'_id': u'Jamaica', u'avg': 937700.0},
#  {u'_id': u'Togo', u'avg': 837437.0},
#  {u'_id': u'Kyrgyzstan', u'avg': 835800.0},
#  {u'_id': u'Dominican Republic', u'avg': 820869.6666666666},
#  {u'_id': u'Pakistan', u'avg': 780520.9078469883},
#  {u'_id': u'Egypt', u'avg': 682002.8125},
#  {u'_id': u'Nigeria', u'avg': 635294.9708333333},
#  {u'_id': u'Malaysia', u'avg': 592408.6333333333},
#  {u'_id': u'North Korea', u'avg': 592281.4444444445},
#  {u'_id': u'Japan', u'avg': 579909.7013128701},
#  {u'_id': u'{Galmudug|Somalia}', u'avg': 545000.0},
#  {u'_id': u'Venezuela', u'avg': 533638.2941176471},
#  {u'_id': u'India national cricket team', u'avg': 524988.0},
#  {u'_id': u'Indonesia', u'avg': 447416.20084175083},
#  {u'_id': u'Panama', u'avg': 395576.0},
#  {u'_id': u'Thailand', u'avg': 390806.78571428574},
#  {u'_id': u'Colombia', u'avg': 389760.31111111114},
#  {u'_id': u'South Korea', u'avg': 372192.12703703705},
#  {u'_id': u'Sudan', u'avg': 363945.0},
#  {u'_id': u'Tanzania', u'avg': 347210.5},
#  {u'_id': u'Guatemala', u'avg': 346560.5},
#  {u'_id': u'Morocco', u'avg': 334771.76190476195},
#  {u'_id': u'Mali', u'avg': 325112.0},
#  {u'_id': u'Cyprus', u'avg': 310355.0},
#  {u'_id': u'Burma', u'avg': 308397.61904761905},
#  {u'_id': u'Papua New Guinea', u'avg': 307643.0},
#  {u'_id': u'Somalia', u'avg': 297764.28571428574},
#  {u'_id': u'Philippines', u'avg': 293881.8671287807},
#  {u'_id': u'Vietnam', u'avg': 260208.14814814818},
#  {u'_id': u'United Arab Emirates', u'avg': 252772.0},
#  {u'_id': u'Bosnia and Herzegovina', u'avg': 249496.6},
#  {u'_id': u'Romania', u'avg': 249408.0},
#  {u'_id': u'Madagascar', u'avg': 240172.6},
#  {u'_id': u'Zimbabwe', u'avg': 236817.625},
#  {u'_id': u'Mexico', u'avg': 234735.41910872312},
#  {u'_id': u'Taiwan', u'avg': 221659.86666666664},
#  {u'_id': u'Ecuador', u'avg': 219074.18686868687},
#  {u'_id': u'Bolivia', u'avg': 218946.875},
#  {u'_id': u'India', u'avg': 201537.8686725376},
#  {u'_id': u'Algeria', u'avg': 196969.7},
#  {u'_id': u'Cambodia', u'avg': 195898.0},
#  {u'_id': u'East Timor', u'avg': 193563.0},
#  {u'_id': u'{Jubaland|Somalia}', u'avg': 183300.0},
#  {u'_id': u'Czech Republic', u'avg': 182720.7142857143},
#  {u'_id': u'Libya', u'avg': 180310.0},
#  {u'_id': u'Afghanistan', u'avg': 177409.9375},
#  {u'_id': u'Iraq', u'avg': 174487.33333333334},
#  {u'_id': u'Ethiopia', u'avg': 170932.0},
#  {u'_id': u'Ivory Coast', u'avg': 164991.89444444442},
#  {u'_id': u'Hungary', u'avg': 157308.56666666668},
#  {u'_id': u'Montenegro', u'avg': 156169.0},
#  {u'_id': u'North Sumatra', u'avg': 152748.0},
#  {u'_id': u'Mauritius', u'avg': 137608.0},
#  {u'_id': u'Serbia', u'avg': 130687.55802469136},
#  {u'_id': u'Angola', u'avg': 125904.66666666667},
#  {u'_id': u'El Salvador', u'avg': 125154.0},
#  {u'_id': u'Canada', u'avg': 123374.22370121692},
#  {u'_id': u'Portugal', u'avg': 121885.78431372548},
#  {u'_id': u'Sri Lanka', u'avg': 120169.07971014493},
#  {u'_id': u'Kuwait', u'avg': 115945.66666666667},
#  {u'_id': u'Estonia', u'avg': 104109.0},
#  {u'_id': u'Macedonia', u'avg': 101501.83333333333},
#  {u'_id': u'Barbados', u'avg': 96578.0},
#  {u'_id': u'Guinea', u'avg': 95234.0},
#  {u'_id': u'Uruguay', u'avg': 95081.87714285715},
#  {u'_id': u'Jordan', u'avg': 93797.71666666666},
#  {u'_id': u'Peru', u'avg': 92130.2},
#  {u'_id': u'Benin', u'avg': 85848.47146464646},
#  {u'_id': u'Eritrea', u'avg': 78857.33333333333},
#  {u'_id': u'Northeast Region Brazil', u'avg': 78139.5},
#  {u'_id': u'Netherlands', u'avg': 77592.02266666667},
#  {u'_id': u'Argentina', u'avg': 76691.87284678411},
#  {u'_id': u'Ukraine', u'avg': 73912.21009199134},
#  {u'_id': u'Slovenia', u'avg': 70727.64285714286},
#  {u'_id': u'Spain', u'avg': 69802.6516154918},
#  {u'_id': u'New Zealand', u'avg': 68901.0},
#  {u'_id': u'Yemen', u'avg': 64053.5},
#  {u'_id': u'Mauritania', u'avg': 62021.666666666664},
#  {u'_id': u'Saint Lucia', u'avg': 61341.0},
#  {u'_id': u'Iceland', u'avg': 58662.0},
#  {u'_id': u'Kosovo', u'avg': 57586.75},
#  {u'_id': u'Botswana', u'avg': 56170.75},
#  {u'_id': u'S\xe3o Tom\xe9 and Pr\xedncipe', u'avg': 56166.0},
#  {u'_id': u'Brazil', u'avg': 55619.25154061624},
#  {u'_id': u'Albania', u'avg': 55210.40909090909},
#  {u'_id': u'Trinidad and Tobago', u'avg': 52360.0},
#  {u'_id': u'Fiji', u'avg': 52220.0},
#  {u'_id': u'Nepal', u'avg': 50598.97019969278},
#  {u'_id': u'Cape Verde', u'avg': 50585.666666666664},
#  {u'_id': u'Laos', u'avg': 50000.0},
#  {u'_id': u'Kazakhstan', u'avg': 49971.2},
#  {u'_id': u'Costa Rica', u'avg': 48973.444444444445},
#  {u'_id': u'Paraguay', u'avg': 46473.125},
#  {u'_id': u'Vanuatu', u'avg': 44040.0},
#  {u'_id': u'Belize', u'avg': 41285.0},
#  {u'_id': u'Croatia', u'avg': 39074.92156862745},
#  {u'_id': u'Namibia', u'avg': 37933.958333333336},
#  {u'_id': u'Bulgaria', u'avg': 37341.0},
#  {u'_id': u'Qatar', u'avg': 31547.0},
#  {u'_id': u'Iran', u'avg': 31174.275647889815},
#  {u'_id': u'Denmark', u'avg': 30570.0},
#  {u'_id': u'Lebanon', u'avg': 29645.083333333332},
#  {u'_id': u'Belgium', u'avg': 29521.0},
#  {u'_id': u'Latvia', u'avg': 27569.0},
#  {u'_id': u'Saint Vincent and the Grenadines', u'avg': 24518.0},
#  {u'_id': u'Austria', u'avg': 24110.0},
#  {u'_id': u'Azerbaijan', u'avg': 22696.98709677419},
#  {u'_id': u'Republic of Macedonia', u'avg': 22017.0},
#  {u'_id': u'Syria', u'avg': 22004.512987012986},
#  {u'_id': u'Moldova', u'avg': 20675.0},
#  {u'_id': u'Uzbekistan', u'avg': 20404.875},
#  {u'_id': u'United States', u'avg': 18212.545703853204},
#  {u'_id': u'Grenada', u'avg': 17367.0},
#  {u'_id': u'Poland', u'avg': 16676.166666666668},
#  {u'_id': u'Sweden', u'avg': 16616.0},
#  {u'_id': u'Chile', u'avg': 16103.314444444444},
#  {u'_id': u'Lithuania', u'avg': 14750.784447977201},
#  {u'_id': u'Southeast Region Brazil', u'avg': 12883.0},
#  {u'_id': u'Liberia', u'avg': 12117.0},
#  {u'_id': u'Norway', u'avg': 8579.5},
#  {u'_id': u'Georgia', u'avg': 8000.0},
#  {u'_id': u'Georgia (country)', u'avg': 4800.0},
#  {u'_id': u'Malta', u'avg': 4384.133333333333},
#  {u'_id': u'Niue', u'avg': 581.0}]

# %%
def make_pipeline():
    # complete the aggregation pipeline
    pipeline = [
        {"$match": {"population": {"$exists": True, "$ne": None},
                    "country": {"$exists": True, "$ne": None}
                   }},
        {"$unwind": "$isPartOf"},
        {"$group": {"_id": "$isPartOf", 
                    "avgInRegion": {"$avg": "$population"}, 
                    "country": {"$first": "$country"}}},
        {"$group": {"_id": "$country", "avgRegionalPopulation": {"$avg": "$avgInRegion"}}},
        {"$sort": {"avgRegionalPopulation": -1}}
    ]
    return pipeline

# %%
def aggregate(db, pipeline):
    return [doc for doc in db.cities.aggregate(pipeline)]

if __name__ == '__main__':
    # The following statements will be used to test your code by the grader.
    # Any modifications to the code past this point will not be reflected by
    # the Test Run.
    db = get_db('examples')
    pipeline = make_pipeline()
    result = aggregate(db, pipeline)
    import pprint
    if len(result) < 150:
        pprint.pprint(result)
    else:
        pprint.pprint(result[:100])
    key_pop = 0
    for country in result:
        if country["_id"] == 'Lithuania':
            assert country["_id"] == 'Lithuania'
            assert abs(country["avgRegionalPopulation"] - 14750.784447977203) < 1e-10
            key_pop = country["avgRegionalPopulation"]
    assert {'_id': 'Lithuania', 'avgRegionalPopulation': key_pop} in result
# Out:
# [{u'_id': u'The_Democratic_Republic_Of_Congo',
#   u'avgRegionalPopulation': 9046000.0},
#  {u'_id': u'Turkey', u'avgRegionalPopulation': 1945457.0},
#  {u'_id': u'United Kingdom', u'avgRegionalPopulation': 1864957.8653846155},
#  {u'_id': u'Saudi Arabia', u'avgRegionalPopulation': 1826254.75},
#  {u'_id': u'Cuba', u'avgRegionalPopulation': 1701228.0},
#  {u'_id': u'China', u'avgRegionalPopulation': 1294543.23975458},
#  {u'_id': u'Kenya', u'avgRegionalPopulation': 1226727.4285714286},
#  {u'_id': u'Bangladesh', u'avgRegionalPopulation': 1193317.0925925926},
#  {u'_id': u'Ghana', u'avgRegionalPopulation': 1185798.5},
#  {u'_id': u'Tunisia', u'avgRegionalPopulation': 1138517.5},
#  {u'_id': u'Honduras', u'avgRegionalPopulation': 1126534.0},
#  {u'_id': u'Zambia', u'avgRegionalPopulation': 1103957.4285714286},
#  {u'_id': u'Jamaica', u'avgRegionalPopulation': 937700.0},
#  {u'_id': u'Togo', u'avgRegionalPopulation': 837437.0},
#  {u'_id': u'Kyrgyzstan', u'avgRegionalPopulation': 835800.0},
#  {u'_id': u'Dominican Republic', u'avgRegionalPopulation': 820869.6666666666},
#  {u'_id': u'Pakistan', u'avgRegionalPopulation': 780520.9078469883},
#  {u'_id': u'Egypt', u'avgRegionalPopulation': 682002.8125},
#  {u'_id': u'Nigeria', u'avgRegionalPopulation': 635294.9708333333},
#  {u'_id': u'Malaysia', u'avgRegionalPopulation': 592408.6333333333},
#  {u'_id': u'North Korea', u'avgRegionalPopulation': 592281.4444444445},
#  {u'_id': u'Japan', u'avgRegionalPopulation': 579909.7013128701},
#  {u'_id': u'{Galmudug|Somalia}', u'avgRegionalPopulation': 545000.0},
#  {u'_id': u'Venezuela', u'avgRegionalPopulation': 533638.2941176471},
#  {u'_id': u'India national cricket team', u'avgRegionalPopulation': 524988.0},
#  {u'_id': u'Indonesia', u'avgRegionalPopulation': 447416.20084175083},
#  {u'_id': u'Panama', u'avgRegionalPopulation': 395576.0},
#  {u'_id': u'Thailand', u'avgRegionalPopulation': 390806.78571428574},
#  {u'_id': u'Colombia', u'avgRegionalPopulation': 389760.31111111114},
#  {u'_id': u'South Korea', u'avgRegionalPopulation': 372192.12703703705},
#  {u'_id': u'Sudan', u'avgRegionalPopulation': 363945.0},
#  {u'_id': u'Tanzania', u'avgRegionalPopulation': 347210.5},
#  {u'_id': u'Guatemala', u'avgRegionalPopulation': 346560.5},
#  {u'_id': u'Morocco', u'avgRegionalPopulation': 334771.76190476195},
#  {u'_id': u'Mali', u'avgRegionalPopulation': 325112.0},
#  {u'_id': u'Cyprus', u'avgRegionalPopulation': 310355.0},
#  {u'_id': u'Burma', u'avgRegionalPopulation': 308397.61904761905},
#  {u'_id': u'Papua New Guinea', u'avgRegionalPopulation': 307643.0},
#  {u'_id': u'Somalia', u'avgRegionalPopulation': 297764.28571428574},
#  {u'_id': u'Philippines', u'avgRegionalPopulation': 293881.8671287807},
#  {u'_id': u'Vietnam', u'avgRegionalPopulation': 260208.14814814818},
#  {u'_id': u'United Arab Emirates', u'avgRegionalPopulation': 252772.0},
#  {u'_id': u'Bosnia and Herzegovina', u'avgRegionalPopulation': 249496.6},
#  {u'_id': u'Romania', u'avgRegionalPopulation': 249408.0},
#  {u'_id': u'Madagascar', u'avgRegionalPopulation': 240172.6},
#  {u'_id': u'Zimbabwe', u'avgRegionalPopulation': 236817.625},
#  {u'_id': u'Mexico', u'avgRegionalPopulation': 234735.41910872312},
#  {u'_id': u'Taiwan', u'avgRegionalPopulation': 221659.86666666664},
#  {u'_id': u'Ecuador', u'avgRegionalPopulation': 219074.18686868687},
#  {u'_id': u'Bolivia', u'avgRegionalPopulation': 218946.875},
#  {u'_id': u'India', u'avgRegionalPopulation': 201537.8686725376},
#  {u'_id': u'Algeria', u'avgRegionalPopulation': 196969.7},
#  {u'_id': u'Cambodia', u'avgRegionalPopulation': 195898.0},
#  {u'_id': u'East Timor', u'avgRegionalPopulation': 193563.0},
#  {u'_id': u'{Jubaland|Somalia}', u'avgRegionalPopulation': 183300.0},
#  {u'_id': u'Czech Republic', u'avgRegionalPopulation': 182720.7142857143},
#  {u'_id': u'Libya', u'avgRegionalPopulation': 180310.0},
#  {u'_id': u'Afghanistan', u'avgRegionalPopulation': 177409.9375},
#  {u'_id': u'Iraq', u'avgRegionalPopulation': 174487.33333333334},
#  {u'_id': u'Ethiopia', u'avgRegionalPopulation': 170932.0},
#  {u'_id': u'Ivory Coast', u'avgRegionalPopulation': 164991.89444444442},
#  {u'_id': u'Hungary', u'avgRegionalPopulation': 157308.56666666668},
#  {u'_id': u'Montenegro', u'avgRegionalPopulation': 156169.0},
#  {u'_id': u'North Sumatra', u'avgRegionalPopulation': 152748.0},
#  {u'_id': u'Mauritius', u'avgRegionalPopulation': 137608.0},
#  {u'_id': u'Serbia', u'avgRegionalPopulation': 130687.55802469136},
#  {u'_id': u'Angola', u'avgRegionalPopulation': 125904.66666666667},
#  {u'_id': u'El Salvador', u'avgRegionalPopulation': 125154.0},
#  {u'_id': u'Canada', u'avgRegionalPopulation': 123374.22370121692},
#  {u'_id': u'Portugal', u'avgRegionalPopulation': 121885.78431372548},
#  {u'_id': u'Sri Lanka', u'avgRegionalPopulation': 120169.07971014493},
#  {u'_id': u'Kuwait', u'avgRegionalPopulation': 115945.66666666667},
#  {u'_id': u'Estonia', u'avgRegionalPopulation': 104109.0},
#  {u'_id': u'Macedonia', u'avgRegionalPopulation': 101501.83333333333},
#  {u'_id': u'Barbados', u'avgRegionalPopulation': 96578.0},
#  {u'_id': u'Guinea', u'avgRegionalPopulation': 95234.0},
#  {u'_id': u'Uruguay', u'avgRegionalPopulation': 95081.87714285715},
#  {u'_id': u'Jordan', u'avgRegionalPopulation': 93797.71666666666},
#  {u'_id': u'Peru', u'avgRegionalPopulation': 92130.2},
#  {u'_id': u'Benin', u'avgRegionalPopulation': 85848.47146464646},
#  {u'_id': u'Eritrea', u'avgRegionalPopulation': 78857.33333333333},
#  {u'_id': u'Northeast Region Brazil', u'avgRegionalPopulation': 78139.5},
#  {u'_id': u'Netherlands', u'avgRegionalPopulation': 77592.02266666667},
#  {u'_id': u'Argentina', u'avgRegionalPopulation': 76691.87284678411},
#  {u'_id': u'Ukraine', u'avgRegionalPopulation': 73912.21009199134},
#  {u'_id': u'Slovenia', u'avgRegionalPopulation': 70727.64285714286},
#  {u'_id': u'Spain', u'avgRegionalPopulation': 69802.6516154918},
#  {u'_id': u'New Zealand', u'avgRegionalPopulation': 68901.0},
#  {u'_id': u'Yemen', u'avgRegionalPopulation': 64053.5},
#  {u'_id': u'Mauritania', u'avgRegionalPopulation': 62021.666666666664},
#  {u'_id': u'Saint Lucia', u'avgRegionalPopulation': 61341.0},
#  {u'_id': u'Iceland', u'avgRegionalPopulation': 58662.0},
#  {u'_id': u'Kosovo', u'avgRegionalPopulation': 57586.75},
#  {u'_id': u'Botswana', u'avgRegionalPopulation': 56170.75},
#  {u'_id': u'S\xe3o Tom\xe9 and Pr\xedncipe',
#   u'avgRegionalPopulation': 56166.0},
#  {u'_id': u'Brazil', u'avgRegionalPopulation': 55619.25154061624},
#  {u'_id': u'Albania', u'avgRegionalPopulation': 55210.40909090909},
#  {u'_id': u'Trinidad and Tobago', u'avgRegionalPopulation': 52360.0},
#  {u'_id': u'Fiji', u'avgRegionalPopulation': 52220.0},
#  {u'_id': u'Nepal', u'avgRegionalPopulation': 50598.97019969278},
#  {u'_id': u'Cape Verde', u'avgRegionalPopulation': 50585.666666666664},
#  {u'_id': u'Laos', u'avgRegionalPopulation': 50000.0},
#  {u'_id': u'Kazakhstan', u'avgRegionalPopulation': 49971.2},
#  {u'_id': u'Costa Rica', u'avgRegionalPopulation': 48973.444444444445},
#  {u'_id': u'Paraguay', u'avgRegionalPopulation': 46473.125},
#  {u'_id': u'Vanuatu', u'avgRegionalPopulation': 44040.0},
#  {u'_id': u'Belize', u'avgRegionalPopulation': 41285.0},
#  {u'_id': u'Croatia', u'avgRegionalPopulation': 39074.92156862745},
#  {u'_id': u'Namibia', u'avgRegionalPopulation': 37933.958333333336},
#  {u'_id': u'Bulgaria', u'avgRegionalPopulation': 37341.0},
#  {u'_id': u'Qatar', u'avgRegionalPopulation': 31547.0},
#  {u'_id': u'Iran', u'avgRegionalPopulation': 31174.275647889815},
#  {u'_id': u'Denmark', u'avgRegionalPopulation': 30570.0},
#  {u'_id': u'Lebanon', u'avgRegionalPopulation': 29645.083333333332},
#  {u'_id': u'Belgium', u'avgRegionalPopulation': 29521.0},
#  {u'_id': u'Latvia', u'avgRegionalPopulation': 27569.0},
#  {u'_id': u'Saint Vincent and the Grenadines',
#   u'avgRegionalPopulation': 24518.0},
#  {u'_id': u'Austria', u'avgRegionalPopulation': 24110.0},
#  {u'_id': u'Azerbaijan', u'avgRegionalPopulation': 22696.98709677419},
#  {u'_id': u'Republic of Macedonia', u'avgRegionalPopulation': 22017.0},
#  {u'_id': u'Syria', u'avgRegionalPopulation': 22004.512987012986},
#  {u'_id': u'Moldova', u'avgRegionalPopulation': 20675.0},
#  {u'_id': u'Uzbekistan', u'avgRegionalPopulation': 20404.875},
#  {u'_id': u'United States', u'avgRegionalPopulation': 18212.545703853204},
#  {u'_id': u'Grenada', u'avgRegionalPopulation': 17367.0},
#  {u'_id': u'Poland', u'avgRegionalPopulation': 16676.166666666668},
#  {u'_id': u'Sweden', u'avgRegionalPopulation': 16616.0},
#  {u'_id': u'Chile', u'avgRegionalPopulation': 16103.314444444444},
#  {u'_id': u'Lithuania', u'avgRegionalPopulation': 14750.784447977201},
#  {u'_id': u'Southeast Region Brazil', u'avgRegionalPopulation': 12883.0},
#  {u'_id': u'Liberia', u'avgRegionalPopulation': 12117.0},
#  {u'_id': u'Norway', u'avgRegionalPopulation': 8579.5},
#  {u'_id': u'Georgia', u'avgRegionalPopulation': 8000.0},
#  {u'_id': u'Georgia (country)', u'avgRegionalPopulation': 4800.0},
#  {u'_id': u'Malta', u'avgRegionalPopulation': 4384.133333333333},
#  {u'_id': u'Niue', u'avgRegionalPopulation': 581.0}]
